# %% [markdown]
# <a href="https://colab.research.google.com/github/theozyme/yolov5/blob/main/YOLOv5_uygulama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-313-g712de55a Python-3.10.12 torch-2.2.1+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.1/107.7 GB disk)

# %%
# unzipping dataset.zip
# !unzip /content/dataset.zip -d /content/

# Fazladan baytları temizleyin
# !dd if=/content/dataset.zip of=/content/clean_dataset.zip bs=1 skip=3447446

# Temizlenmiş dosyayı açmayı deneyin
# !unzip /content/clean_dataset.zip -d /content/clean_dataset_extracted

# Eğer hata devam ederse, 7z aracı ile açmayı deneyin
# !apt-get install -y p7zip-full
!7z x /content/clean_dataset.zip -o/content/clean_dataset_extracted
# Out:
# Archive:  /content/dataset.zip
#   inflating: /content/dataset/dataset.yaml
#    creating: /content/dataset/images/
#    creating: /content/dataset/images/train/
#   inflating: /content/dataset/images/train/00000.jpg
#   inflating: /content/dataset/images/train/00001.jpg
#   inflating: /content/dataset/images/train/00003.jpg
#   inflating: /content/dataset/images/train/00005.jpg
#   inflating: /content/dataset/images/train/00006.jpg
#   inflating: /content/dataset/images/train/00007.jpg
#   inflating: /content/dataset/images/train/00008.jpg
#   inflating: /content/dataset/images/train/00009.jpg
#   inflating: /content/dataset/images/train/00010.jpg
#   inflating: /content/dataset/images/train/00011.jpg
#   inflating: /content/dataset/images/train/00012.jpg
#   inflating: /content/dataset/images/train/00014.jpg
#   inflating: /content/dataset/images/train/00015.jpg
#   inflating: /content/dataset/images/train/00016.jpg
#   inflating: /content/dataset/images/train/00017.jpg
# ...

# %%
# yolov5s
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/dataset/dataset.yaml --weights yolov5s.pt --cache --patience 10
# Out:
# 2024-05-19 10:18:39.389330: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-19 10:18:39.389422: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-19 10:18:39.548287: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# yolov5m
# !python detect.py --weights yolov5m.pt --img 640 --conf 0.25 --source /content/dataset/images/train
# Out:
# detect: weights=['yolov5m.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-313-g712de55a Python-3.10.12 torch-2.2.1+cu121 CPU
#
# ...
# 100% 40.8M/40.8M [00:00<00:00, 177MB/s]
#
# Fusing layers...
# YOLOv5m summary: 290 layers, 21172173 parameters, 0 gradients, 48.9 GFLOPs
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, 1263.2ms
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 3 persons, 2 ties, 795.2ms
# Speed: 4.8ms pre-process, 1029.2ms inference, 1.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
# yolov5l
# !python detect.py --weights yolov5l.pt --img 640 --conf 0.25 --source /content/dataset/images/train
# Out:
# detect: weights=['yolov5l.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-313-g712de55a Python-3.10.12 torch-2.2.1+cu121 CPU
#
# ...
# 100% 89.3M/89.3M [00:00<00:00, 280MB/s]
#
# Fusing layers...
# YOLOv5l summary: 367 layers, 46533693 parameters, 0 gradients, 109.0 GFLOPs
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, 2528.9ms
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 1 tie, 1161.9ms
# Speed: 2.8ms pre-process, 1845.4ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
#@title Select YOLOv5 🚀 logger {run: 'auto'}
logger = 'Comet' #@param ['Comet', 'ClearML', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'ClearML':
  # %pip install -q clearml
  import clearml; clearml.browser_login()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train
# Out:
# Please paste your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)
# Comet API key: ··········
# COMET INFO: Valid Comet API Key saved in /root/.comet.config (set COMET_CONFIG to change where it is saved).

# %%
# Train YOLOv5s on our dataset for 40 epochs
# !python train.py --img 640 --batch 16 --epochs 40 --data /content/yolov5/data/dataset.yaml --weights yolov5s.pt --cache
# Out:
# 2024-05-18 15:40:33.712024: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-18 15:40:33.712071: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-18 15:40:33.713587: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Train YOLOv5m on our dataset for 40 epochs
# !python train.py --img 640 --batch 16 --epochs 40 --data /content/yolov5/data/dataset.yaml --weights yolov5m.pt --cache
# Out:
# 2024-05-18 15:53:07.048563: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-18 15:53:07.048624: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-18 15:53:07.050825: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Train YOLOv5l on our dataset for 40 epochs
# !python train.py --img 640 --batch 16 --epochs 40 --data /content/yolov5/data/dataset.yaml --weights yolov5l.pt --cache
# Out:
# 2024-05-18 16:19:56.883222: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-18 16:19:56.883274: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-18 16:19:56.884760: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --source 0
# Out:
# python3: can't open file '/content/detect.py': [Errno 2] No such file or directory
